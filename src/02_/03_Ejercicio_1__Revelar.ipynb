# %%
import numpy as np
import skimage #scikit-image
from skimage.io import imread
import matplotlib.pyplot as plt

# %% [markdown]
# ### Lectura de la imagen

# %%
# !wget http://www.guidetofilmphotography.com/photos/bw-negative.jpg
# Out:
# --2023-09-18 11:20:03--  http://www.guidetofilmphotography.com/photos/bw-negative.jpg
# Resolving www.guidetofilmphotography.com (www.guidetofilmphotography.com)... 50.87.149.192
# Connecting to www.guidetofilmphotography.com (www.guidetofilmphotography.com)|50.87.149.192|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102246 (100K) [image/jpeg]
# Saving to: 'bw-negative.jpg.1'
#
#      0K .......... .......... .......... .......... .......... 50%  140K 0s
#     50K .......... .......... .......... .......... ......... 100%  249M=0.4s
#
# 2023-09-18 11:20:04 (279 KB/s) - 'bw-negative.jpg.1' saved [102246/102246]

# %%
im_original = imread('bw-negative.jpg')
im_original = im_original[:,::,:]
plt.imshow(im_original)

# %%
im = imread('bw-negative.jpg')
im = im[:,:500,0]
plt.imshow(im, cmap='gray')

# %% [markdown]
# ### Revelar la imagen

# %%
im
# Out:
# array([[194, 194, 194, ..., 246, 248, 254],
#        [182, 182, 182, ..., 247, 248, 254],
#        [184, 184, 185, ..., 247, 249, 254],
#        ...,
#        [115, 170, 208, ..., 202, 201, 205],
#        [112, 168, 207, ..., 202, 202, 207],
#        [104, 158, 202, ..., 202, 204, 211]], dtype=uint8)

# %%
#modificar
im_revelado = 255 - im
im_revelado2 = -im

# %%
im_revelado
# Out:
# array([[ 61,  61,  61, ...,   9,   7,   1],
#        [ 73,  73,  73, ...,   8,   7,   1],
#        [ 71,  71,  70, ...,   8,   6,   1],
#        ...,
#        [140,  85,  47, ...,  53,  54,  50],
#        [143,  87,  48, ...,  53,  53,  48],
#        [151,  97,  53, ...,  53,  51,  44]], dtype=uint8)

# %%
im_revelado2
# Out:
# array([[ 62,  62,  62, ...,  10,   8,   2],
#        [ 74,  74,  74, ...,   9,   8,   2],
#        [ 72,  72,  71, ...,   9,   7,   2],
#        ...,
#        [141,  86,  48, ...,  54,  55,  51],
#        [144,  88,  49, ...,  54,  54,  49],
#        [152,  98,  54, ...,  54,  52,  45]], dtype=uint8)

# %% [markdown]
# ### Mostrar imagen revelada

# %%
plt.imshow(im_revelado, cmap='gray')

# %%
plt.imshow(im_revelado2, cmap='gray')
